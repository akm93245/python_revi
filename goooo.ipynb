# %%
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import numpy as np

# %%
s1 = Series(range(0,4)) # -> 0, 1, 2, 3
s2 = Series(range(1,5)) # -> 1, 2, 3, 4
s3 = s1 + s2 # -> 1, 3, 5, 7
s4 = Series(['a','b'])*3 # -> 'aaa','bbb'

# %%
s3
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
s4
# Out:
# 0    aaa
# 1    bbb
# dtype: object

# %%
idx = s1.index
idx.sort
# Out:
# <bound method Index.sort of RangeIndex(start=0, stop=4, step=1)>

# %%
idx.is_monotonic_decreasing
# Out:
# False

# %%
ttt = sns.load_dataset('titanic')

# %%
ttt.groupby(['class', 'survived']).count()
# Out:
# C:\Users\123\AppData\Local\Temp\ipykernel_2708\1982134015.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ttt.groupby(['class', 'survived']).count()
#                  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class  survived
# First  0             80   80   64     80     80    80        80   80
#        1            136  136  122    136    136   136       134  136
# Second 0             97   97   90     97     97    97        97   97
#        1             87   87   83     87     87    87        87   87
# Third  0            372  372  270    372    372   372       372  372
#        1            119  119   85    119    119   119       119  119
#
#                  adult_male  deck  embark_town  alive  alone
# class  survived
# ...

# %%
sns.histplot(x="sex"  , hue= 'class' , data= ttt)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
aa = pd.DataFrame(np.random.rand(4,5))

# %%
aa
# Out:
#           0         1         2         3         4
# 0  0.262378  0.685502  0.467175  0.651966  0.649767
# 1  0.948064  0.596508  0.937769  0.664485  0.616144
# 2  0.416836  0.841643  0.973927  0.230621  0.113966
# 3  0.264956  0.614726  0.714871  0.718220  0.136104

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
ttt.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
ttt.to_numpy()
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
ttt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ar = np.array([[1,2,4,5],[5,7,8,0]])

# %%
ar
# Out:
# array([[1, 2, 4, 5],
#        [5, 7, 8, 0]])

# %%
pd.DataFrame(ar)
# Out:
#    0  1  2  3
# 0  1  2  4  5
# 1  5  7  8  0

# %%
ff = sns.load_dataset('iris')
ff.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ff.species.describe()
# Out:
# count        150
# unique         3
# top       setosa
# freq          50
# Name: species, dtype: object

# %%
ff.groupby('species').count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
sns.barplot(x='sepal_width' , y= 'sepal_length' , hue='species', data=ff)
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
tt = pd.read_excel('D:\coding files\AK CODE\practice_sessions\prac_session_01\copa_group_a.xlsx')

# %%
tt
# Out:
#    Unnamed: 0       Team  Matches played  Won  Draw  Lost  Points
# 0           0  Argentina               3    3     0     0       9
# 1           1     Canada               3    1     1     1       4
# 2           2      Chile               3    0     2     1       2
# 3           3       Peru               3    0     1     2       1

# %%
sns.histplot(x='Won', y='Matches played', hue='Team', data= tt)
# Out:
# <Axes: xlabel='Won', ylabel='Matches played'>
