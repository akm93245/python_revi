# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
fmnist = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)= fmnist.load_data()

assert train_images.shape == (60000,28,28)
assert test_images.shape ==(10000,28,28)
assert train_labels == (60000,)
assert train_images ==(10000,)

print("Train data : X=%s, y = %s "% (train_images.shape,train_labels.shape))
print("test data : X=%s , y=%s "%(test_images.shape, test_labels.shape))

# %%
for i range(9):
    plt.subplot(330+1+i)
    plt.imshow(train_images[i],cmap=plt.get_cmap('gray'))
    plt.axis('off')
    plt.tight_layout()
    plt.show

# %%
for i in range(9):
    plt.subplot(330 +1 +i)
    plt.imshow(train_images[i],cmap=plt.get_cmap('gray'))
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
for i in range(9):
    plt.subplot(330, 1,i)
    plt.imshow(train_images[i], cmap=plt.get_cmap('gray'))
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
model = keras.Sequential([
keras.layers.Flatten(input_shape=(28,28))
keras.layers.Dense(128, Activation='relu')
keras.layers.Dense(10,Activation='softmax')
])

# compling the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images,train_labels,epochs= 10)
#evaulute
test_loss ,test_acc = model.evaluate(X_test,y_test)
# accuracy
print('accuracy : ',test_acc)

# %%
model.compile(optimizer= 'adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images,train_labels,epochs = 10)
loss, acc = model.evaluate(X_test,y_test)
print('accuracy : ',acc)

# %%
predicion= model.predict(X_test)
print(predicion[:10])
class_label = [tf.argmax(predicion )for predic in predicion]
print(class_label[:10])

# %%
predic= model.predict(X_test)
print(prd)
