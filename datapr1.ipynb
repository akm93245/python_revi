# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data1.xlsx')

# %%
df.head()
# Out:
#   DATA COLLECTION "ASSESSING THE CASUE OF REFUSAL OF REGIONAL ANESTHESIA IN MALE ORTHOPEDIC PATIENT PRESENTING IN ORTHOPDIC OT"  \
# 0                                                NaN
# 1                                                NaN
# 2                                               S.NO
# 3                                                  1
# 4                                                  2
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0          NaN        NaN        NaN        NaN         NaN         NaN
# 1          NaN        NaN        NaN        NaN         NaN         NaN
# 2         NAME      MR.NO  EDUCATION        AGE  ASA STATUS  GCS STATUS
# 3  LUQMAN KHAN    7460012       ZERO         45           2          15
# 4   TALHA KHAN    7444971    PRIMERY         18           1          15
#
#             Unnamed: 7        Unnamed: 8  \
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2  SURGICAL PROCECDURE  PREVIOUS SURGERY
# 3           LOWER LIMB                NO
# 4           LOWER LIMB               YES
#
#                                      Unnamed: 9  \
# 0                                           NaN
# 1                                           NaN
# 2  WHAT TYPE OF ANESTHESIA WAS GIVEN PREVIOUSLY
# 3                                           NaN
# 4                                            GA
#
#                              Unnamed: 10              Unnamed: 11  \
# 0                                    NaN                      NaN
# 1                                    NaN                      NaN
# 2  SATISFICTION WITH PREVIOUS ANESTHESIA  KNOWLEDGE OF ANESTHESIA
# 3                                    NaN                      YES
# 4                                    YES                      YES
#
#                       Unnamed: 12 Unnamed: 13                   Unnamed: 14
# 0                             NaN         NaN                           NaN
# 1                             NaN         NaN                           NaN
# 2  WHERE THE INFORMATION WAS  GET  PREFERENCE       REASON OF REFUSAL OF RA
# 3           HEALTH CARE PERSONNEL          GA                      BACKACHE
# 4           HEALTH CARE PERSONNEL          GA  BEING AWAKE INTRAOPERATIVELY

# %%
df.shape
# Out:
# (137, 15)

# %%
df
# Out:
#     DATA COLLECTION "ASSESSING THE CASUE OF REFUSAL OF REGIONAL ANESTHESIA IN MALE ORTHOPEDIC PATIENT PRESENTING IN ORTHOPDIC OT"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                 S.NO
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 132                                                132
# 133                                                133
# 134                                                134
# 135                                                135
# 136                                                136
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0            NaN        NaN        NaN        NaN         NaN         NaN
# 1            NaN        NaN        NaN        NaN         NaN         NaN
# 2           NAME      MR.NO  EDUCATION        AGE  ASA STATUS  GCS STATUS
# 3    LUQMAN KHAN    7460012       ZERO         45           2          15
# 4     TALHA KHAN    7444971    PRIMERY         18           1          15
# ..           ...        ...        ...        ...         ...         ...
# 132          NaN        NaN        NaN        NaN         NaN         NaN
# 133          NaN        NaN        NaN        NaN         NaN         NaN
# 134          NaN        NaN        NaN        NaN         NaN         NaN
# 135          NaN        NaN        NaN        NaN         NaN         NaN
# 136          NaN        NaN        NaN        NaN         NaN         NaN
#
#               Unnamed: 7        Unnamed: 8  \
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2    SURGICAL PROCECDURE  PREVIOUS SURGERY
# 3             LOWER LIMB                NO
# 4             LOWER LIMB               YES
# ..                   ...               ...
# 132                  NaN               NaN
# 133                  NaN               NaN
# 134                  NaN               NaN
# 135                  NaN               NaN
# 136                  NaN               NaN
#
#                                        Unnamed: 9  \
# 0                                             NaN
# 1                                             NaN
# 2    WHAT TYPE OF ANESTHESIA WAS GIVEN PREVIOUSLY
# 3                                             NaN
# 4                                              GA
# ..                                            ...
# 132                                           NaN
# 133                                           NaN
# 134                                           NaN
# 135                                           NaN
# 136                                           NaN
#
#                                Unnamed: 10              Unnamed: 11  \
# 0                                      NaN                      NaN
# 1                                      NaN                      NaN
# 2    SATISFICTION WITH PREVIOUS ANESTHESIA  KNOWLEDGE OF ANESTHESIA
# 3                                      NaN                      YES
# 4                                      YES                      YES
# ..                                     ...                      ...
# 132                                    NaN                      NaN
# 133                                    NaN                      NaN
# 134                                    NaN                      NaN
# 135                                    NaN                      NaN
# 136                                    NaN                      NaN
#
#                         Unnamed: 12 Unnamed: 13                   Unnamed: 14
# 0                               NaN         NaN                           NaN
# 1                               NaN         NaN                           NaN
# 2    WHERE THE INFORMATION WAS  GET  PREFERENCE       REASON OF REFUSAL OF RA
# 3             HEALTH CARE PERSONNEL          GA                      BACKACHE
# 4             HEALTH CARE PERSONNEL          GA  BEING AWAKE INTRAOPERATIVELY
# ..                              ...         ...                           ...
# 132                             NaN         NaN                           NaN
# 133                             NaN         NaN                           NaN
# 134                             NaN         NaN                           NaN
# 135                             NaN         NaN                           NaN
# 136                             NaN         NaN                           NaN
#
# [137 rows x 15 columns]

# %%
df.describe()
# Out:
#        DATA COLLECTION "ASSESSING THE CASUE OF REFUSAL OF REGIONAL ANESTHESIA IN MALE ORTHOPEDIC PATIENT PRESENTING IN ORTHOPDIC OT"  \
# count                                                 135
# unique                                                135
# top                                                  S.NO
# freq                                                    1
#
#          Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# count           109         107        106        107        108        108
# unique          108         105          7         52          6          8
# top     yaseen khan     7456403       ZERO         18          1         15
# freq              2           2         44         13         60         72
#
#         Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# count           97        106         16          16         107          12
# unique           3          3          2           2           3           5
# top     LOWER LIMB         NO         GA         YES          NO      OTHERS
# freq            68         90         15          15          96           5
#
#        Unnamed: 13                   Unnamed: 14
# count          107                           107
# unique           2                             7
# top             GA  BEING AWAKE INTRAOPERATIVELY
# freq           106                            59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 15 columns):
#  #   Column                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                         --------------  -----
#  0   DATA COLLECTION "ASSESSING THE CASUE OF REFUSAL OF REGIONAL ANESTHESIA IN MALE ORTHOPEDIC PATIENT PRESENTING IN ORTHOPDIC OT"  135 non-null    object
#  1   Unnamed: 1                                                                                                                     109 non-null    object
#  2   Unnamed: 2                                                                                                                     107 non-null    object
#  3   Unnamed: 3                                                                                                                     106 non-null    object
#  4   Unnamed: 4                                                                                                                     107 non-null    object
#  5   Unnamed: 5                                                                                                                     108 non-null    object
#  6   Unnamed: 6                                                                                                                     108 non-null    object
#  7   Unnamed: 7                                                                                                                     97 non-null     object
#  8   Unnamed: 8                                                                                                                     106 non-null    object
#  9   Unnamed: 9                                                                                                                     16 non-null     object
#  10  Unnamed: 10                                                                                                                    16 non-null     object
#  11  Unnamed: 11                                                                                                                    107 non-null    object
#  12  Unnamed: 12                                                                                                                    12 non-null     object
#  13  Unnamed: 13                                                                                                                    107 non-null    object
#  14  Unnamed: 14                                                                                                                    107 non-null    object
# dtypes: object(15)
# memory usage: 16.2+ KB

# %%
dff = sns.load_dataset('titanic')

# %%
dff
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
dff.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64
