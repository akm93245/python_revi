# %% [markdown]
# ## Pandas With Alishba

# %% [markdown]
# -----

# %% [markdown]
# > for life (I'm In............)
#
# `Sok lewanai shi os sok lewantoob shi`\
# `sok shi pa khob oda sok rangeen khob she`
#
# `Zama Zor zama Zwani sta pa Husan Qurbani`
#
# ` A^2 `

# %% [markdown]
# ------------------

# %% [markdown]
# **Importing the **libraries****

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# import dataset of Gender based Employment in Pakistan

# %%
df = pd.read_csv("D:/coding files/AK CODE/practice_sessions/EDA/Gender based employment in pakistan/GenderBasedEmploymentInPakistan2023.csv")

# %%
df
# Out:
#          Province            Division District               Indicator  \
# 0     Balochistan      Kalat Division    Kalat  Working Age Population
# 1     Balochistan      Kalat Division    Kalat  Working Age Population
# 2     Balochistan      Kalat Division    Kalat            Labour Force
# 3     Balochistan      Kalat Division    Kalat            Labour Force
# 4     Balochistan      Kalat Division    Kalat                Employed
# ...           ...                 ...      ...                     ...
# 4725        Sindh  Hyderabad Division   Matiri        Total Population
# 4726        Sindh   Banbhore Division  Thattah        Total Population
# 4727        Sindh   Banbhore Division  Thattah        Total Population
# 4728  Balochistan     Quetta Division   Lorali        Total Population
# 4729  Balochistan     Quetta Division   Lorali        Total Population
#
#      Area Type   Total    Male  Female
# 0        Rural  130000   70000   59000
# ...

# %%
df.head()
# Out:
#       Province        Division District               Indicator Area Type  \
# 0  Balochistan  Kalat Division    Kalat  Working Age Population     Rural
# 1  Balochistan  Kalat Division    Kalat  Working Age Population     Urban
# 2  Balochistan  Kalat Division    Kalat            Labour Force     Rural
# 3  Balochistan  Kalat Division    Kalat            Labour Force     Urban
# 4  Balochistan  Kalat Division    Kalat                Employed     Rural
#
#     Total   Male Female
# 0  130000  70000  59000
# 1   28000  17000  12000
# 2   52600  49600   3100
# 3   10800  10600    300
# 4   49700  47400   2300

# %%
df.tail(6)
# Out:
#          Province            Division District         Indicator Area Type  \
# 4724        Sindh  Hyderabad Division   Matiri  Total Population     Rural
# 4725        Sindh  Hyderabad Division   Matiri  Total Population     Urban
# 4726        Sindh   Banbhore Division  Thattah  Total Population     Rural
# 4727        Sindh   Banbhore Division  Thattah  Total Population     Urban
# 4728  Balochistan     Quetta Division   Lorali  Total Population     Rural
# 4729  Balochistan     Quetta Division   Lorali  Total Population     Urban
#
#        Total    Male  Female
# 4724  587371  302477  284834
# 4725  182669   94445   88207
# 4726  654818  340701  314105
# 4727  176476   90900   85556
# 4728  332532  176186  156332
# 4729   64891   36316   28573

# %%
df.shape
# Out:
# (4730, 8)

# %% [markdown]
# It has just told us that theres is 4730 rows and 8 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4730 entries, 0 to 4729
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Province   4730 non-null   object
#  1   Division   4730 non-null   object
#  2   District   4730 non-null   object
#  3   Indicator  4730 non-null   object
#  4   Area Type  4730 non-null   object
#  5   Total      4730 non-null   object
#  6   Male       4730 non-null   object
#  7   Female     4730 non-null   object
# dtypes: object(8)
# memory usage: 295.8+ KB

# %% [markdown]
# we can see that all the columns have datatype of object which should not be .\
# we will work on that

# %%
df.describe()
# Out:
#        Province         Division        District         Indicator Area Type  \
# count      4730             4730            4730              4730      4730
# unique        4               30             131                20         3
# top      Punjab  Quetta Division  Qilla Abdullah  Total Population     Rural
# freq       1334              400              38               276      2103
#
#        Total  Male Female
# count   4730  4730   4730
# unique  1838  1848   1626
# top        -     -      -
# freq     322   343    742

# %% [markdown]
# study the above

# %% [markdown]
# -----

# %% [markdown]
# we will be changing the datatypes of "total", "Male","Female"

# %% [markdown]
# changing the datatypes

# %%
df.Male.unique()
# Out:
# array(['70000', '17000', '49600', ..., '90900', '176186', '36316'],
#       dtype=object)

# %%
rm1 = df[(df["Male"]=="-")]

# %%
df = df.drop(df[(df["Male"]=="-")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df = df.drop(df[(df["Male"]=="-")])
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...
