# %% [markdown]
# **Creating a simple function **

# %%
def greet():
    print("Hello dear friend ")
 

Na = input("your name ")

print(greet(),"Waqas")
# Out:
# Hello dear friend
# None Waqas

# %% [markdown]
# ---

# %% [markdown]
# **Creating a function which take takes input and have a parameter**

# %%
def show(name , f_name, job,goal):
    # input(name)
    # input(f_name)
    # input(job)
    # input(goal)'''
    
    print("name : ",name)
    print("Father name : ",f_name)
    print("Job title : ",job)
    print("Life goal : ",goal)
    
n=input("Enter your name :")
f= input("Enter your father name : ")
j = input("Enter your job name : ")
g = input("Your life goal : ")
show(n,f,j,g)
# Out:
# name :  Ahmad
# Father name :  M Ibrahim
# Job title :  Ds
# Life goal :  Die

# %% [markdown]
# ---
