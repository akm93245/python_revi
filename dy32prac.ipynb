# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
fmnist = keras.datasets.fashion_mnist
(X_train,y_train),(X_test,y_test)= fmnist.load_data()

# %%
index = 5000
np.set_printoptions(linewidth = 320)
print(f"label : {y_train[index]}")
print(f"trained image \n {X_train[index]}")

plt.imshow(X_train[index])

# %%
index = 50000
np.set_printoption(linewidth = 320)
print(f"label {y_train[index]}")
print(f"image \n{X_train[index]}")

plt.imshow(X_train[index])

# %% [markdown]
# Using callback to get the desired accuracy

# %%
class mycallback(tf.keras.callbacks.callback):
    def on_epoch_end(self,epochs,logs=None):
        if (logs.get('loss')<2.5):
            print("n\ loss is lower than 2.5 so cancelling the training")
            self.model.stop_training= True

mycallback()

# %%
class mycallback(tf.keras.callbacks.callback):
    def on_epoch_end(self,epochs,logs=None):
        if(logs.get('loss')<1.5):
            print("got the dicided accuracy")
            self.model.stop_training =True


callback = mycallback()

# %%
class mycallback(tf.keras.callbacks.callback):
    def on_epoch_end(self,epochs,logs=None):
        if(log.get('loss')0.09):
            print("\n got the desired accuracy")
            self.model.stop_training= True
callback = mycallback()

# %%
class mycallback(tf.keras.callbacks.callback):
    def on_epoch_end(self,epochs,logs=None):
        if(logs.get('loss')<0.112):
            print("got the desired accuracy")
            self.model.stop_training= True

callback = mycallback()

# %%
class mycallback(tf.keras.callbacks.callback):
    def on_epoch_end(self,epochs , logs=None):
        if(logs.get('loss')<0.34):
            print('got it')
            self.model.stop_training =True
callback = mycallback
