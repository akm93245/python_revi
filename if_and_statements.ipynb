# %% [markdown]
# # Code for Universities Selection

# %%
# variables 

your_age = int(input("Enter"))
age_req = 19

# %% [markdown]
# ### using if and elif functions

# %%
if your_age > 0 and your_age < 7 :
    print("Play kiddo and Enjoy the days of inocense")

if your_age > 7 and your_age < 16 :
    print("Go to school kiddo ")

if your_age > 16 and your_age < 19 :
    print("college time boy ")


if your_age >= 19 and your_age <= 30 :
    print("my boy you are welcome to join")

if your_age > 30 and your_age < 45 :
    print("create some kids")

if your_age > 45 and your_age < 70 :
    print("play with grand kids")

if your_age >= 70 :
    print("Just Die")
# Out:
# Just Die
