# %%
NN = [12,23,21,14]
JN = ['LR','sup vec', 'RFC', "Knezdegawond"]
MN = ['LogisticRegression','SVC','RandomForestClassifier','KNN']
for x , y ,z in zip (MN,JN,NN):
    print(f"model accuracy : {z}")
# Out:
# model accuracy : 12
# model accuracy : 23
# model accuracy : 21
# model accuracy : 14
